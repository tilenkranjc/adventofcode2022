# %% [markdown]
# # Part 1

# %%
a = open("input.txt", "r")
count=0
while true
    count+=1
    prev_line=line
    line=readline(a)
    
    if line==""
        break
    end
end
a = open("input.txt", "r")
line=readline(a)
prev_line=line

n_stacks=length(prev_line)÷4+1
stacks=Array{String}(undef,n_stacks)

#stacks=[string(prev_line[(x*4)+2]) for x in range(0,n_stacks-1)]
chars=""
count=0
while true
    count+=1
    prev_line=line
    line=readline(a)
    if line==""
        break
    end
    
    chars=[string(prev_line[(x*4)+2]) for x in range(0,n_stacks-1)]
    #print(chars)
    try
        for s in eachindex(stacks)
            stacks[s]=strip(stacks[s]*chars[s])
        end
    catch e
        stacks=[string(prev_line[(x*4)+2]) for x in range(0,n_stacks-1)]
    end
    
    
end
close(a)

a = open("input.txt", "r")
line=""
while true
    line=readline(a)
    if line==""
        break
    end
end
print(line)

count=0

while !eof(a)
    line=readline(a)
    count+=1
    m=match(r"move ([0-9]*) from ([0-9]*) to ([0-9]*)",line)
    n,source,dest=m.captures
    n=parse(Int64,n)
    source=parse(Int64,source)
    dest=parse(Int64,dest)
    stacks[dest]=reverse(string(stacks[source][1:n]))*stacks[dest]
    stacks[source]=stacks[source][n+1:end]
end
close(a)
print(String([x[1] for x in stacks]))
# Out:
# ZRLJGSCTR

# %% [markdown]
# # Part 2

# %%
a = open("input.txt", "r")
count=0
while true
    count+=1
    prev_line=line
    line=readline(a)
    
    if line==""
        break
    end
end
a = open("input.txt", "r")
line=readline(a)
prev_line=line

n_stacks=length(prev_line)÷4+1
stacks=Array{String}(undef,n_stacks)

#stacks=[string(prev_line[(x*4)+2]) for x in range(0,n_stacks-1)]
chars=""
count=0
while true
    count+=1
    prev_line=line
    line=readline(a)
    if line==""
        break
    end
    
    chars=[string(prev_line[(x*4)+2]) for x in range(0,n_stacks-1)]
    #print(chars)
    try
        for s in eachindex(stacks)
            stacks[s]=strip(stacks[s]*chars[s])
        end
    catch e
        stacks=[string(prev_line[(x*4)+2]) for x in range(0,n_stacks-1)]
    end
    
    
end
close(a)

a = open("input.txt", "r")
line=""
while true
    line=readline(a)
    if line==""
        break
    end
end
print(line)

count=0

while !eof(a)
    line=readline(a)
    count+=1
    m=match(r"move ([0-9]*) from ([0-9]*) to ([0-9]*)",line)
    n,source,dest=m.captures
    n=parse(Int64,n)
    source=parse(Int64,source)
    dest=parse(Int64,dest)
    stacks[dest]=(string(stacks[source][1:n]))*stacks[dest]
    stacks[source]=stacks[source][n+1:end]
end
close(a)
print(String([x[1] for x in stacks]))
# Out:
# PRTTGRFPB
